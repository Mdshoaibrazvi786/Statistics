# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sec_a=np.array([75,65,73,68,72,76])
sec_b=np.array([90,47,43,96,93,91])
no=np.array([1,2,3,4,5,6])

# %%
#Standard deviation

# %%
np.std(sec_a) , np.std(sec_b)
# Out:
# (3.8622100754188224, 22.499382707581606)

# %%
#Variances

# %%
np.var(sec_a) , np.var(sec_b)
# Out:
# (14.916666666666666, 506.2222222222222)

# %%
mean=np.mean(sec_b)
mean
# Out:
# 76.66666666666667

# %%
#Mean Absoulte deviation

# %%
mad_a = np.sum(np.abs(sec_a-mean))/len(sec_a)
mad_b = np.sum(np.abs(sec_b-mean))/len(sec_b)

# %%
mad_a, mad_b
# Out:
# (5.166666666666671, 21.11111111111111)

# %%
plt.figure(figsize=(10,3))
plt.scatter(sec_a,no,label="sec A")
plt.scatter(sec_b,no,color="red",label="sec B")
plt.plot([70,70,70,70,70,70],no,c="blue",label="Mean")
plt.legend()
plt.show()
