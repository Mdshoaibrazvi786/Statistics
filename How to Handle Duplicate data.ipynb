# %%
import pandas as pd

# %%
data = {"name":["a","b","c","d","a","c"],"eng":[8,9,7,5,5,4],"hindi":[2,3,4,4,5,67]}

# %%
df = pd.DataFrame(data)
df
# Out:
#   name  eng  hindi
# 0    a    8      2
# 1    b    9      3
# 2    c    7      4
# 3    d    5      4
# 4    a    5      5
# 5    c    4     67
